# %% [markdown]
# ## 知识图谱构建
# ### 下面我们将根据一份非结构化数据，构建一个知识图谱
# ```
# 一般而言，我们拿到的数据是非结构化的，可能来自业务部门，也可能来自网络爬虫，针对用非结构化数据如何结构化，并导入到图数据库里，首选的技术栈是关系抽取和实体抽取，以及三元组的联合抽取，但这部分技术栈不是本次课程的重点，因此我们在构建图谱的时候，直接给出了已经结构化的数据。
# ```

# %% [markdown]
# #### 知识图谱schema
# 根据上面样本数据的特点，我们设计图谱如下：
# * Disease（疾病）
#
# |  属性   | 含义  |  例子  |
# |  ----  | ----  | ----  |
# | name  | 疾病名称 | "百日咳" |
# | intro  | 简介 | "百日咳(pertussis，whoopingcough)是…" |
# | cause  | 起因 | " (一)发病原因\n病原菌是鲍特菌属(Bordetella)…" |
# | prevent  | 预防 | "百日咳预防\n1、控制传染源…" |
# | nursing  | 护理 | "确诊的患者应立即隔离至病后40天…" |
# | insurance  | 是否医保 | "否" |
# | easy_get  | 易感人群 | "多见于小儿" |
# | get_way  | 感染途径 | "呼吸道传播" |
# | get_prob  | 感染概率 | "0.5%" |
# | treat  | 治疗方式 | "药物治疗", "支持性治疗" |
# | treat_prob  | 治愈概率 | "98%" |
# | treat_period  | 治疗时间 | "1-2个月" |
# | treat_cost  | 疾病名称 | "根据不同医院，收费标准不一致，市三甲…" |
# | treat_detail  | 治疗细节 | "百日咳西医治疗 1、药物治疗…" |
#
#
# * Department（科室）
#
# |  属性   | 含义  |  例子  |
# |  ----  | ----  | ----  |
# | name  | 科室名称 | "小儿内科" |
#
#
# * Drug（药物）
#
# |  属性   | 含义  |  例子  |
# |  ----  | ----  | ----  |
# | name  | 药物名称 | "阿司匹林肠溶片" |
#
#
# * Food（食物）
#
# |  属性   | 含义  |  例子  |
# |  ----  | ----  | ----  |
# | name  | 食物名称 | "小米面" |
#
# * Symptom（症状）
#
# |  属性   | 含义  |  例子  |
# |  ----  | ----  | ----  |
# | name  | 症状名称 | "指甲呈筒形" |
#
# * 关系设计（Relationship Design）：共有6种关系。
#
# |  属性   | 含义  |  例子  |
# |  ----  | ----  | ----  |
# | has_symptom  | 有症状 | ("大叶性肺炎", "有症状", "高热")  |
# | can_use_drug  | 可用药 | ("大叶性肺炎", "可以用药", "乳酸左氧氟沙星片") |
# | belongs_to  | 属于 | ("大叶性肺炎", "属于", "呼吸内科") |
# | has_neopathy  | 有并发症 | ("大叶性肺炎", "有并发症", "肺脓肿") |
# | can_eat  | 可以吃 | ("大叶性肺炎", "可以吃", "鲫鱼") |
# | not_eat  | 不能吃 | ("大叶性肺炎", "不能吃", "韭菜") |

# %%
# 构建图谱
# !python process_data/process.py process_data
# Out:
# create disease node count=50
# create disease node count=100
# create disease node count=150
# create disease node count=200
# create disease node count=250
# create disease node count=300
# create disease node count=350
# create disease node count=400
# create disease node count=450
# create disease node count=500
# create disease node count=550
# create disease node count=600
# create disease node count=650
# create disease node count=700
# create disease node count=750
# create disease node count=800
# create disease node count=850
# create disease node count=900
# create disease node count=950
# create disease node count=1000
# create disease node count=1050
# create disease node count=1100
# create disease node count=1150
# create disease node count=1200
# create disease node count=1250
# create disease node count=1300
# create disease node count=1350
# create disease node count=1400
# create disease node count=1450
# create disease node count=1500
# create disease node count=1550
# create disease node count=1600
# create disease node count=1650
# create disease node count=1700
# create disease node count=1750
# create disease node count=1800
# create disease node count=1850
# create disease node count=1900
# create disease node count=1950
# create disease node count=2000
# create disease node count=2050
# create disease node count=2100
# create disease node count=2150
# create disease node count=2200
# create disease node count=2250
# create disease node count=2300
# create disease node count=2350
# create disease node count=2400
# create disease node count=2450
# create disease node count=2500
# create disease node count=2550
# create disease node count=2600
# create disease node count=2650
# create disease node count=2700
# create disease node count=2750
# create disease node count=2800
# create disease node count=2850
# create disease node count=2900
# create disease node count=2950
# create disease node count=3000
# create disease node count=3050
# create disease node count=3100
# create disease node count=3150
# create disease node count=3200
# create disease node count=3250
# create disease node count=3300
# create disease node count=3350
# create disease node count=3400
# create disease node count=3450
# create disease node count=3500
# create disease node count=3550
# create disease node count=3600
# create disease node count=3650
# create disease node count=3700
# create disease node count=3750
# create disease node count=3800
# create disease node count=3850
# create disease node count=3900
# create disease node count=3950
# create disease node count=4000
# create disease node count=4050
# create disease node count=4100
# create disease node count=4150
# create disease node count=4200
# create disease node count=4250
# create disease node count=4300
# create disease node count=4350
# create disease node count=4400
# create disease node count=4450
# create disease node count=4500
# create disease node count=4550
# create disease node count=4600
# create disease node count=4650
# create disease node count=4700
# create disease node count=4750
# create disease node count=4800
# create disease node count=4850
# create disease node count=4900
# create disease node count=4950
# create disease node count=5000
# create disease node count=5050
# create disease node count=5100
# create disease node count=5150
# create disease node count=5200
# create disease node count=5250
# create disease node count=5300
# create disease node count=5350
# create disease node count=5400
# create disease node count=5450
# create disease node count=5500
# create disease node count=5550
# create disease node count=5600
# create disease node count=5650
# create disease node count=5700
# create disease node count=5750
# create disease node count=5800
# create disease node count=5850
# create disease node count=5900
# create disease node count=5950
# create disease node count=6000
# create disease node count=6050
# create disease node count=6100
# create total disease node count=6143
# create total Department node count=54
# create Drug node count=500
# create Drug node count=1000
# create total Drug node count=1124
# create Symptom node count=500
# create Symptom node count=1000
# create Symptom node count=1500
# create Symptom node count=2000
# create Symptom node count=2500
# create Symptom node count=3000
# create Symptom node count=3500
# create Symptom node count=4000
# create Symptom node count=4500
# create Symptom node count=5000
# create Symptom node count=5500
# create total Symptom node count=5936
# create total Food node count=378
# create Producer node count=500
# create total Producer node count=708
# create rel_type: has_neopathy, count: 500/13094
# create rel_type: has_neopathy, count: 1000/13094
# create rel_type: has_neopathy, count: 1500/13094
# create rel_type: has_neopathy, count: 2000/13094
# create rel_type: has_neopathy, count: 2500/13094
# create rel_type: has_neopathy, count: 3000/13094
# create rel_type: has_neopathy, count: 3500/13094
# create rel_type: has_neopathy, count: 4000/13094
# create rel_type: has_neopathy, count: 4500/13094
# create rel_type: has_neopathy, count: 5000/13094
# create rel_type: has_neopathy, count: 5500/13094
# create rel_type: has_neopathy, count: 6000/13094
# create rel_type: has_neopathy, count: 6500/13094
# create rel_type: has_neopathy, count: 7000/13094
# create rel_type: has_neopathy, count: 7500/13094
# create rel_type: has_neopathy, count: 8000/13094
# create rel_type: has_neopathy, count: 8500/13094
# create rel_type: has_neopathy, count: 9000/13094
# create rel_type: has_neopathy, count: 9500/13094
# create rel_type: has_neopathy, count: 10000/13094
# create rel_type: has_neopathy, count: 10500/13094
# create rel_type: has_neopathy, count: 11000/13094
# create rel_type: has_neopathy, count: 11500/13094
# create rel_type: has_neopathy, count: 12000/13094
# create rel_type: has_neopathy, count: 12500/13094
# create rel_type: has_neopathy, count: 13000/13094
# finish creating rel_type: has_neopathy, count: 13094
# create rel_type: has_symptom, count: 500/40120
# create rel_type: has_symptom, count: 1000/40120
# create rel_type: has_symptom, count: 1500/40120
# create rel_type: has_symptom, count: 2000/40120
# create rel_type: has_symptom, count: 2500/40120
# create rel_type: has_symptom, count: 3000/40120
# create rel_type: has_symptom, count: 3500/40120
# create rel_type: has_symptom, count: 4000/40120
# create rel_type: has_symptom, count: 4500/40120
# create rel_type: has_symptom, count: 5000/40120
# create rel_type: has_symptom, count: 5500/40120
# create rel_type: has_symptom, count: 6000/40120
# create rel_type: has_symptom, count: 6500/40120
# create rel_type: has_symptom, count: 7000/40120
# create rel_type: has_symptom, count: 7500/40120
# create rel_type: has_symptom, count: 8000/40120
# create rel_type: has_symptom, count: 8500/40120
# create rel_type: has_symptom, count: 9000/40120
# create rel_type: has_symptom, count: 9500/40120
# create rel_type: has_symptom, count: 10000/40120
# create rel_type: has_symptom, count: 10500/40120
# create rel_type: has_symptom, count: 11000/40120
# create rel_type: has_symptom, count: 11500/40120
# create rel_type: has_symptom, count: 12000/40120
# create rel_type: has_symptom, count: 12500/40120
# create rel_type: has_symptom, count: 13000/40120
# create rel_type: has_symptom, count: 13500/40120
# create rel_type: has_symptom, count: 14000/40120
# create rel_type: has_symptom, count: 14500/40120
# create rel_type: has_symptom, count: 15000/40120
# create rel_type: has_symptom, count: 15500/40120
# create rel_type: has_symptom, count: 16000/40120
# create rel_type: has_symptom, count: 16500/40120
# create rel_type: has_symptom, count: 17000/40120
# create rel_type: has_symptom, count: 17500/40120
# create rel_type: has_symptom, count: 18000/40120
# create rel_type: has_symptom, count: 18500/40120
# create rel_type: has_symptom, count: 19000/40120
# create rel_type: has_symptom, count: 19500/40120
# create rel_type: has_symptom, count: 20000/40120
# create rel_type: has_symptom, count: 20500/40120
# create rel_type: has_symptom, count: 21000/40120
# create rel_type: has_symptom, count: 21500/40120
# create rel_type: has_symptom, count: 22000/40120
# create rel_type: has_symptom, count: 22500/40120
# create rel_type: has_symptom, count: 23000/40120
# create rel_type: has_symptom, count: 23500/40120
# create rel_type: has_symptom, count: 24000/40120
# create rel_type: has_symptom, count: 24500/40120
# create rel_type: has_symptom, count: 25000/40120
# create rel_type: has_symptom, count: 25500/40120
# create rel_type: has_symptom, count: 26000/40120
# create rel_type: has_symptom, count: 26500/40120
# create rel_type: has_symptom, count: 27000/40120
# create rel_type: has_symptom, count: 27500/40120
# create rel_type: has_symptom, count: 28000/40120
# create rel_type: has_symptom, count: 28500/40120
# create rel_type: has_symptom, count: 29000/40120
# create rel_type: has_symptom, count: 29500/40120
# create rel_type: has_symptom, count: 30000/40120
# create rel_type: has_symptom, count: 30500/40120
# create rel_type: has_symptom, count: 31000/40120
# create rel_type: has_symptom, count: 31500/40120
# create rel_type: has_symptom, count: 32000/40120
# create rel_type: has_symptom, count: 32500/40120
# create rel_type: has_symptom, count: 33000/40120
# create rel_type: has_symptom, count: 33500/40120
# create rel_type: has_symptom, count: 34000/40120
# create rel_type: has_symptom, count: 34500/40120
# create rel_type: has_symptom, count: 35000/40120
# create rel_type: has_symptom, count: 35500/40120
# create rel_type: has_symptom, count: 36000/40120
# create rel_type: has_symptom, count: 36500/40120
# create rel_type: has_symptom, count: 37000/40120
# create rel_type: has_symptom, count: 37500/40120
# create rel_type: has_symptom, count: 38000/40120
# create rel_type: has_symptom, count: 38500/40120
# create rel_type: has_symptom, count: 39000/40120
# create rel_type: has_symptom, count: 39500/40120
# create rel_type: has_symptom, count: 40000/40120
# finish creating rel_type: has_symptom, count: 40120
# create rel_type: can_use_drug, count: 500/9564
# create rel_type: can_use_drug, count: 1000/9564
# create rel_type: can_use_drug, count: 1500/9564
# create rel_type: can_use_drug, count: 2000/9564
# create rel_type: can_use_drug, count: 2500/9564
# create rel_type: can_use_drug, count: 3000/9564
# create rel_type: can_use_drug, count: 3500/9564
# create rel_type: can_use_drug, count: 4000/9564
# create rel_type: can_use_drug, count: 4500/9564
# create rel_type: can_use_drug, count: 5000/9564
# create rel_type: can_use_drug, count: 5500/9564
# create rel_type: can_use_drug, count: 6000/9564
# create rel_type: can_use_drug, count: 6500/9564
# create rel_type: can_use_drug, count: 7000/9564
# create rel_type: can_use_drug, count: 7500/9564
# create rel_type: can_use_drug, count: 8000/9564
# create rel_type: can_use_drug, count: 8500/9564
# create rel_type: can_use_drug, count: 9000/9564
# create rel_type: can_use_drug, count: 9500/9564
# finish creating rel_type: can_use_drug, count: 9564
# finish creating rel_type: belongs_to, count: 35
# create rel_type: belongs_to, count: 500/6021
# create rel_type: belongs_to, count: 1000/6021
# create rel_type: belongs_to, count: 1500/6021
# create rel_type: belongs_to, count: 2000/6021
# create rel_type: belongs_to, count: 2500/6021
# create rel_type: belongs_to, count: 3000/6021
# create rel_type: belongs_to, count: 3500/6021
# create rel_type: belongs_to, count: 4000/6021
# create rel_type: belongs_to, count: 4500/6021
# create rel_type: belongs_to, count: 5000/6021
# create rel_type: belongs_to, count: 5500/6021
# create rel_type: belongs_to, count: 6000/6021
# finish creating rel_type: belongs_to, count: 6021
# create rel_type: can_eat, count: 500/24363
# create rel_type: can_eat, count: 1000/24363
# create rel_type: can_eat, count: 1500/24363
# create rel_type: can_eat, count: 2000/24363
# create rel_type: can_eat, count: 2500/24363
# create rel_type: can_eat, count: 3000/24363
# create rel_type: can_eat, count: 3500/24363
# create rel_type: can_eat, count: 4000/24363
# create rel_type: can_eat, count: 4500/24363
# create rel_type: can_eat, count: 5000/24363
# create rel_type: can_eat, count: 5500/24363
# create rel_type: can_eat, count: 6000/24363
# create rel_type: can_eat, count: 6500/24363
# create rel_type: can_eat, count: 7000/24363
# create rel_type: can_eat, count: 7500/24363
# create rel_type: can_eat, count: 8000/24363
# create rel_type: can_eat, count: 8500/24363
# create rel_type: can_eat, count: 9000/24363
# create rel_type: can_eat, count: 9500/24363
# create rel_type: can_eat, count: 10000/24363
# create rel_type: can_eat, count: 10500/24363
# create rel_type: can_eat, count: 11000/24363
# create rel_type: can_eat, count: 11500/24363
# create rel_type: can_eat, count: 12000/24363
# create rel_type: can_eat, count: 12500/24363
# create rel_type: can_eat, count: 13000/24363
# create rel_type: can_eat, count: 13500/24363
# create rel_type: can_eat, count: 14000/24363
# create rel_type: can_eat, count: 14500/24363
# create rel_type: can_eat, count: 15000/24363
# create rel_type: can_eat, count: 15500/24363
# create rel_type: can_eat, count: 16000/24363
# create rel_type: can_eat, count: 16500/24363
# create rel_type: can_eat, count: 17000/24363
# create rel_type: can_eat, count: 17500/24363
# create rel_type: can_eat, count: 18000/24363
# create rel_type: can_eat, count: 18500/24363
# create rel_type: can_eat, count: 19000/24363
# create rel_type: can_eat, count: 19500/24363
# create rel_type: can_eat, count: 20000/24363
# create rel_type: can_eat, count: 20500/24363
# create rel_type: can_eat, count: 21000/24363
# create rel_type: can_eat, count: 21500/24363
# create rel_type: can_eat, count: 22000/24363
# create rel_type: can_eat, count: 22500/24363
# create rel_type: can_eat, count: 23000/24363
# create rel_type: can_eat, count: 23500/24363
# create rel_type: can_eat, count: 24000/24363
# finish creating rel_type: can_eat, count: 24363
# create rel_type: not_eat, count: 500/24376
# create rel_type: not_eat, count: 1000/24376
# create rel_type: not_eat, count: 1500/24376
# create rel_type: not_eat, count: 2000/24376
# create rel_type: not_eat, count: 2500/24376
# create rel_type: not_eat, count: 3000/24376
# create rel_type: not_eat, count: 3500/24376
# create rel_type: not_eat, count: 4000/24376
# create rel_type: not_eat, count: 4500/24376
# create rel_type: not_eat, count: 5000/24376
# create rel_type: not_eat, count: 5500/24376
# create rel_type: not_eat, count: 6000/24376
# create rel_type: not_eat, count: 6500/24376
# create rel_type: not_eat, count: 7000/24376
# create rel_type: not_eat, count: 7500/24376
# create rel_type: not_eat, count: 8000/24376
# create rel_type: not_eat, count: 8500/24376
# create rel_type: not_eat, count: 9000/24376
# create rel_type: not_eat, count: 9500/24376
# create rel_type: not_eat, count: 10000/24376
# create rel_type: not_eat, count: 10500/24376
# create rel_type: not_eat, count: 11000/24376
# create rel_type: not_eat, count: 11500/24376
# create rel_type: not_eat, count: 12000/24376
# create rel_type: not_eat, count: 12500/24376
# create rel_type: not_eat, count: 13000/24376
# create rel_type: not_eat, count: 13500/24376
# create rel_type: not_eat, count: 14000/24376
# create rel_type: not_eat, count: 14500/24376
# create rel_type: not_eat, count: 15000/24376
# create rel_type: not_eat, count: 15500/24376
# create rel_type: not_eat, count: 16000/24376
# create rel_type: not_eat, count: 16500/24376
# create rel_type: not_eat, count: 17000/24376
# create rel_type: not_eat, count: 17500/24376
# create rel_type: not_eat, count: 18000/24376
# create rel_type: not_eat, count: 18500/24376
# create rel_type: not_eat, count: 19000/24376
# create rel_type: not_eat, count: 19500/24376
# create rel_type: not_eat, count: 20000/24376
# create rel_type: not_eat, count: 20500/24376
# create rel_type: not_eat, count: 21000/24376
# create rel_type: not_eat, count: 21500/24376
# create rel_type: not_eat, count: 22000/24376
# create rel_type: not_eat, count: 22500/24376
# create rel_type: not_eat, count: 23000/24376
# create rel_type: not_eat, count: 23500/24376
# create rel_type: not_eat, count: 24000/24376
# finish creating rel_type: not_eat, count: 24376
# create rel_type: drug_producer, count: 500/1119
# create rel_type: drug_producer, count: 1000/1119
# finish creating rel_type: drug_producer, count: 1119

# %% [markdown]
# ### 图谱效果
# 查询语句：
# > MATCH p=()-[:can_use_drug]->() RETURN p LIMIT 25
#
# ![](./img/can_use_drug.png)

# %% [markdown]
# #### 拿到我们这样一个图谱之后，怎么构建KBQA呢？
# * 如果我们通过NLU做句子分类，发现当前用户输入时查疾病-症状的关系，并且用户输入的句子包含了疾病实体：
#  ```json
# 大叶性肺炎有哪些症状哦
#  ```
# 上面的问句，从意图来看，属于查询：疾病-症状
# 从实体提取看，能识别到疾病：大叶性肺炎
# 因此为了回答上面的问题，我们可以将其转为针对我们图谱的一个查询，这样就完整了我们KBQA的一个最简单的建模过程啦。
# ###### 对应的查询语句为：
# > MATCH (p:Disease{name: "大叶性肺炎"})-[:has_symptom]->(s:Symptom) return s.name
#
# ![](./img/has_symptom.png)
